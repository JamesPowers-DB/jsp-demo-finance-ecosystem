# %%
# %sql
SELECT * FROM jsp_demo.legal_bronze.raw_inbound_contracts LIMIT 100

# %%
# %sql
SELECT * FROM jsp_demo.legal_bronze.raw_outbound_contracts LIMIT 100

# %%
# %sql
SELECT * FROM jsp_demo.legal_gold.dim_all_contracts LIMIT 100

# %%
# %sql
SELECT *
FROM  jsp_demo.legal_bronze.raw_outbound_contracts LIMIT 100

# %%
# %sql
SELECT * FROm jsp_demo.acct_bronze.raw_legal_entities
